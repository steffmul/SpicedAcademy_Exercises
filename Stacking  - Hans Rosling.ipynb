# %% [markdown]
# Refers to
# file:///C:/Users/steff/Documents/DataScience%20Bootcamp/datascience/data_handling_with_python/pandas/long_vs_wide_tables/README.html?highlight=long

# %% [markdown]
# #### Load data

# %%
import pandas as pd
from matplotlib import pyplot as plt

fert = pd.read_csv('gapminder_total_fertility.csv', index_col=0)

# %%
life = pd.read_excel('gapminder_lifeexpectancy.xlsx' , index_col=0)
life.head(3)
# Out:
#                         1800  1801   1802   1803   1804   1805   1806   1807  \
# Life expectancy
# Abkhazia                 NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN
# Afghanistan            28.21  28.2  28.19  28.18  28.17  28.16  28.15  28.14
# Akrotiri and Dhekelia    NaN   NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#                         1808   1809  ...    2007  2008  2009  2010  2011  \
# Life expectancy                      ...
# Abkhazia                 NaN    NaN  ...     NaN   NaN   NaN   NaN   NaN
# Afghanistan            28.13  28.12  ...    52.4  52.8  53.3  53.6  54.0
# Akrotiri and Dhekelia    NaN    NaN  ...     NaN   NaN   NaN   NaN   NaN
#
#                        2012  2013  2014  2015   2016
# Life expectancy
# Abkhazia                NaN   NaN   NaN   NaN    NaN
# Afghanistan            54.4  54.8  54.9  53.8  52.72
# Akrotiri and Dhekelia   NaN   NaN   NaN   NaN    NaN
#
# [3 rows x 217 columns]

# %% [markdown]
# #### check shape

# %%
print(life.shape)
# Out:
# (260, 217)

# %%
print(fert.shape)
# Out:
# (260, 216)

# %%
fert.columns
# Out:
# Index(['1800', '1801', '1802', '1803', '1804', '1805', '1806', '1807', '1808',
#        '1809',
#        ...
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
#        '2015'],
#       dtype='object', length=216)

# %%
life.columns
# Out:
# Int64Index([1800, 1801, 1802, 1803, 1804, 1805, 1806, 1807, 1808, 1809,
#             ...
#             2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016],
#            dtype='int64', length=217)

# %% [markdown]
# #### transform column format

# %%
ncol = [int(x) for x in fert.columns]
fert
# Out:
#                           1800  1801  1802  1803  1804  1805  1806  1807  \
# Total fertility rate
# Abkhazia                   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Afghanistan               7.00  7.00  7.00  7.00  7.00  7.00  7.00  7.00
# Akrotiri and Dhekelia      NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Albania                   4.60  4.60  4.60  4.60  4.60  4.60  4.60  4.60
# Algeria                   6.99  6.99  6.99  6.99  6.99  6.99  6.99  6.99
# American Samoa             NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Andorra                    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Angola                    6.93  6.93  6.93  6.93  6.93  6.93  6.93  6.94
# Anguilla                   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# Antigua and Barbuda       5.00  5.00  4.99  4.99  4.99  4.98  4.98  4.97
# Argentina                 6.80  6.80  6.80  6.80  6.80  6.80  6.80  6.80
# ...

# %%
fert.set_axis(axis=1, labels=ncol, inplace=True)

# %%
fert.columns
# Out:
# Int64Index([1800, 1801, 1802, 1803, 1804, 1805, 1806, 1807, 1808, 1809,
#             ...
#             2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015],
#            dtype='int64', length=216)

# %% [markdown]
# ####  hierarchical index

# %%
sfert = fert.stack()
slife = life.stack()

# %%
d = {'fertility': sfert, 'lifeexp': slife}
df2 = pd.DataFrame(data=d)

# %%
d
# Out:
# {'fertility': Total fertility rate
#  Afghanistan           1800    7.00
#                        1801    7.00
#                        1802    7.00
#                        1803    7.00
#                        1804    7.00
#                        1805    7.00
#                        1806    7.00
#                        1807    7.00
#                        1808    7.00
#                        1809    7.00
#                        1810    7.00
#                        1811    7.00
#                        1812    7.00
#                        1813    7.00
#                        1814    7.00
#                        1815    7.00
#                        1816    7.00
#                        1817    7.00
#                        1818    7.00
#                        1819    7.00
#                        1820    7.00
#                        1821    7.00
#                        1822    7.00
#                        1823    7.00
#                        1824    7.00
# ...

# %% [markdown]
# #### import population data and check

# %%
pop = pd.read_excel('gapminder_population.xlsx', index_col=0)
pop.head(3)
# Out:
#                             1800       1810       1820       1830       1840  \
# Total population
# Abkhazia                     NaN        NaN        NaN        NaN        NaN
# Afghanistan            3280000.0  3280000.0  3323519.0  3448982.0  3625022.0
# Akrotiri and Dhekelia        NaN        NaN        NaN        NaN        NaN
#
#                             1850       1860       1870       1880       1890  \
# Total population
# Abkhazia                     NaN        NaN        NaN        NaN        NaN
# Afghanistan            3810047.0  3973968.0  4169690.0  4419695.0  4710171.0
# Akrotiri and Dhekelia        NaN        NaN        NaN        NaN        NaN
#
#                           ...            2006        2007        2008  \
# Total population          ...
# Abkhazia                  ...             NaN         NaN         NaN
# Afghanistan               ...      25183615.0  25877544.0  26528741.0
# ...

# %%
print(pop.shape)
# Out:
# (275, 81)

# %%
pop.columns
# Out:
# Int64Index([1800, 1810, 1820, 1830, 1840, 1850, 1860, 1870, 1880, 1890, 1900,
#             1910, 1920, 1930, 1940, 1950, 1951, 1952, 1953, 1954, 1955, 1956,
#             1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967,
#             1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978,
#             1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989,
#             1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000,
#             2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#             2012, 2013, 2014, 2015],
#            dtype='int64')

# %%
#pop.set_index('Total population', inplace=True)

# %%
ncol = [int(x) for x in pop.columns]

# %%
pop.set_axis(axis=1, labels=ncol, inplace=True)

# %%
pop.columns
# Out:
# Int64Index([1800, 1810, 1820, 1830, 1840, 1850, 1860, 1870, 1880, 1890, 1900,
#             1910, 1920, 1930, 1940, 1950, 1951, 1952, 1953, 1954, 1955, 1956,
#             1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967,
#             1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978,
#             1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989,
#             1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000,
#             2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#             2012, 2013, 2014, 2015],
#            dtype='int64')

# %%
type(pop.columns[0])
# Out:
# numpy.int64

# %%
spop = pop.stack()

# %%
d = {'fertility': sfert, 'lifeexp': slife, 'population': spop}
df2 = pd.DataFrame(data=d)

# %% [markdown]
# #### Convert

# %%
df3 = df2.stack()

# %%
df4 = df3.unstack((0,2))

# %%
#df4

# %% [markdown]
# #### select and scatterplot data

# %%
#df4

# %%
import pylab as plt
# %matplotlib inline

df4[['Germany', 'France', 'Sweden']].plot()

# %%
df5 = df3.unstack(2)

# %%
#df3

# %%
df5.plot.scatter('fertility', 'lifeexp', s=0.1)

# %%
df6 = df3.unstack(1)
df6 = df6[1950]
df6 = df6.unstack(1)
df6.plot.scatter('fertility', 'lifeexp', s=0.1)

# %% [markdown]
# ####  improve our graphics

# %%
cmap = plt.get_cmap('tab20', lut = len(df6['population'])).colors

# %%
#df6.plot.scatter('fertility', 'lifeexp', s=df6['population'])

# %%
df6.head(5)
# Out:
#                        fertility  lifeexp  population
# Afghanistan                 7.67    26.85   7752118.0
# Akrotiri and Dhekelia        NaN      NaN     10661.0
# Albania                     5.80    54.48   1263171.0
# Algeria                     7.65    42.77   8872247.0
# American Samoa               NaN      NaN     18937.0

# %% [markdown]
# #### input for animated scatterplot

# %%
#year = list(range(1960, 2016))
#for i in year:    
#    df6 = df3.unstack(1)
#    df6 = df6[i]
#    df6 = df6.unstack(1)
#    df6.plot.scatter('fertility', 'lifeexp', s=0.1)
#    plt.savefig(f'myplot_{i}.png')
# Out:
# C:\Users\steff\Anaconda3\lib\site-packages\matplotlib\pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %%
year = list(range(1960, 2016))
for i in year:    
    df6 = df3.unstack(1)
    df6 = df6[i]
    df6 = df6.unstack(1)
    s=df6['population']/1000000
    df6.plot.scatter('fertility', 'lifeexp', s=s)
    plt.savefig(f'myplot_{i}.png')

# %%
import imageio

images = []

year = list(range(1960, 2016))

for i in year:
    filename = f'lifeexp_{i}.png'.format(i)
    images.append(imageio.imread(f'myplot_{i}.png'))

imageio.mimsave('output.gif', images, fps=20)
